# %% [markdown]
# **Function 7: Sometimes Lazy is Best**
#
# You are now optimising six hyper-parameters of a machine learning model. Note that it is a popular and frequently used model, so maybe you could search to see if anyone else has optisized it before?

# %%
import numpy as np

from get_init_data import get_inputs, get_outputs

f_num = 7

X_init = get_inputs(f_num)
y_init = get_outputs(f_num)
# print(X_init)
# print(y_init)

# %%
from get_query_data import get_inputs, get_outputs

X_q = get_inputs(f_num)
y_q = get_outputs(f_num)
# print(X_q)
# print(y_q)

# %%
from get_init_data2 import get_inputs, get_outputs

X_init2 = get_inputs(f_num)
y_init2 = get_outputs(f_num)
# print(X_init2)
# print(y_init2)

# %%
X = np.concatenate((X_init, X_q, X_init2), axis=0)
y = np.concatenate((y_init, y_q, y_init2), axis=0)

print("Input : Output")
for i, v in enumerate(X):
    print(str(v) + ":" + str(y[i]))
# print("INPUTS")
# print(X)
# print("OUTPUTS")
# print(y)
# Out:
# Input : Output
# [0.2726238220336933 0.3244953623087271 0.8971088103082926
#  0.8329511521103058 0.1540626853924547 0.7958636234722036]:0.6044326958745716
# [0.5430025769847714 0.9246939036961066 0.3415674591580987
#  0.6464858491139559 0.7184403268342174 0.343132663729359]:0.5627530668655433
# [0.09083224802375334 0.661529381768249 0.0659309106387106
#  0.2585770079605848 0.9634528513541345 0.6402653979255966]:0.007503236678049401
# [0.11886697487294917 0.6150549401610158 0.905816385208328
#  0.8553003035780179 0.41363142879453507 0.5852356278450974]:0.06142430250355775
# [0.6302176411815951 0.8380968963061266 0.6800130516496496
#  0.7318950900926644 0.5267367145175407 0.3484292133580069]:0.27304680126759867
# [0.7649191728046694 0.25588291701198074 0.6090842238764527
#  0.21807904189508076 0.3229427691734139 0.09579365511638072]:0.08374657232015563
# [0.057895541971385245 0.49167221863901367 0.24742222374867484
#  0.21811843639837636 0.42042832954601583 0.7309698428701273]:1.3649683044991994
# [0.19525188113467162 0.07922665059137424 0.5545804616685562
#  0.17056681968240583 0.014944176429292355 0.10703171010323376]:0.09264495494793601
# [0.6423029815827472 0.8368745468225558 0.021792691485860827
#  0.10148800953865356 0.6830708282995157 0.6924164003473481]:0.017869598722495817
# [0.7899425542216801 0.19554500526335772 0.5756233261057669
#  0.07365918727355969 0.2590491743381623 0.05109986421364299]:0.03356493603703717
# [0.528497327736147 0.45742435534127646 0.3600956902472011
#  0.36204550639420896 0.8168909784453008 0.6374763663139539]:0.07351630421016164
# [0.7226152153368091 0.011812836708676278 0.06364591290841193
#  0.16517310603711322 0.07924414600207474 0.3599516573745739]:0.20630969795359433
# [0.075664921203212 0.33450211886956494 0.13273273734822777
#  0.6083123613447988 0.9183859177326257 0.8223307855119826]:0.008825633999510857
# [0.9424508393797228 0.3774396214241422 0.4861223262441836
#  0.22879108306138052 0.08263174710408516 0.7119575508609557]:0.26840031693744637
# [0.14864702139126218 0.03394336343938997 0.7288056495692345
#  0.3160664556651587 0.021769382750669197 0.516917757345384]:0.6115255284647864
# [0.8171123887819559 0.548168230898132 0.10334757767053271
#  0.12436954581241633 0.7282348211044535 0.4496736121668913]:0.01479818260270181
# [0.41762629271823204 0.06409998138921869 0.2456687739007659
#  0.5590407960737909 0.19153138403844328 0.2546409230877973]:0.2748925084715891
# [0.7262856636678173 0.46489580525881 0.9245705141349381 0.807245395137576
# [0.20131011018981815 0.20614846729722613 0.7696877793445404
#  0.33429615575330796 0.48743550434098915 0.13151584382404524]:0.19203277869389368
# [0.19159696811589078 0.25271151738933273 0.3909525523166505
#  0.229105731716016 0.3632873802088622 0.8619460364890174]:2.1146906674520287
# [0.36660459855214045 0.8950202046427739 0.25725146187369197
#  0.7435910678982028 0.9091335059272716 0.8811305745122819]:0.0021497926907202533

# %%
from ba_optimizer_v1 import BayesianOptimizer

optimizer = BayesianOptimizer(np.array(X, dtype=np.float64), y, bounds=(0, 1))

# Re-optimize with updated data
new_submission = optimizer.optimize_step(
    num_candidates=100000,
    acquisition_func='ei'
)

print(f"\nNEW RECOMMENDATION: {new_submission['best_point']}")
print(f"UCB Score: {new_submission['best_acquisition']:.4f}")
# Out:
# ============================================================
# BAYESIAN OPTIMIZATION STEP
# ============================================================
# 1. Computing function metrics...
#    Current best: 2.1147
#    Dataset size: 76
#    Estimated noise: 0.0000
#
# 2. Updating surrogate model...
# GP fitted with kernel: 0.922**2 * RBF(length_scale=0.362) + WhiteKernel(noise_level=1e-10)
# Log-marginal likelihood: -38.5667
#
# 3. Generating 100000 candidate samples...
# 4. Computing EI acquisition function...
# 5. Selecting best points for submission...
#
# RECOMMENDED NEXT POINT:
# Location: [0.02163746 0.25128021 0.47068029 0.20730897 0.3192979  0.82442042]
# Acquisition: 0.0648
# GP Prediction: 2.1223 ± 0.1528
#
# NEW RECOMMENDATION: [0.02163746 0.25128021 0.47068029 0.20730897 0.3192979  0.82442042]
# UCB Score: 0.0648

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern

kernel_matern = 1.0 * Matern(length_scale=1.0, nu=1.5)  # Adjust nu for smoothness
gpr = GaussianProcessRegressor(kernel=kernel_matern, n_restarts_optimizer=10)
gpr.fit(X, y)
# Out:
# GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=1.5),
#                          n_restarts_optimizer=10)

# %%
from scipy.stats import norm
import itertools as it

x1 = np.linspace(0, 1, 15)

list(it.product(['1','2','3','4',], ['a', 'b','c','d']))

dim = 6
X_grid = np.fromiter(it.chain(*it.product(x1, repeat=dim)), dtype=float).reshape(-1,dim)
mean, std = gpr.predict(X_grid, return_std = True)

ucb1 = mean + 1.16 * std

idx_max = np.argmax(ucb1)
next_query = X_grid[idx_max]
print("UCB - Next Query: ", next_query)
# Out:
# UCB - Next Query:  [0.07142857 0.21428571 0.5        0.21428571 0.35714286 0.85714286]

# %%
f_best = np.max(y)

def compute_expected_loss(x):
    mu, sigma = gpr.predict([x], return_std=True)
    z = (mu - f_best) / sigma
    expected_loss = (mu - f_best) * norm.cdf(z) + sigma * norm.pdf(z)
    return expected_loss

expected_loss_values = [compute_expected_loss(x) for x in X_grid]

next_idx = np.argmin(expected_loss_values)
next_query = X_grid[next_idx]

print("Bayesian Expected Loss", next_query)

########Acquisition Function 5 - Expected Improvement
def compute_expected_improvement(x):
    mu, sigma = gpr.predict([x], return_std=True)
    f_best = np.max(y)
    sigma = sigma + 1e-9
    z = (mu - f_best) / sigma
    ei = (mu - f_best) * norm.cdf(z) + sigma * norm.pdf(z)
    return ei

ei_values = [compute_expected_improvement(x) for x in X_grid]

next_idx = np.argmax(ei_values)
next_query = X_grid[next_idx]

print("Expected Improvement", next_query)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 9
#       6     expected_loss = (mu - f_best) * norm.cdf(z) + sigma * norm.pdf(z)
#       7     return expected_loss
# ----> 9 expected_loss_values = [compute_expected_loss(x) for x in X_grid]
#      11 next_idx = np.argmin(expected_loss_values)
#      12 next_query = X_grid[next_idx]
#
# Cell In[54], line 9, in <listcomp>(.0)
#       6     expected_loss = (mu - f_best) * norm.cdf(z) + sigma * norm.pdf(z)
#       7     return expected_loss
# ----> 9 expected_loss_values = [compute_expected_loss(x) for x in X_grid]
#      11 next_idx = np.argmin(expected_loss_values)
#      12 next_query = X_grid[next_idx]
#
# Cell In[54], line 4, in compute_expected_loss(x)
#       3 def compute_expected_loss(x):
# ----> 4     mu, sigma = gpr.predict([x], return_std=True)
#       5     z = (mu - f_best) / sigma
#       6     expected_loss = (mu - f_best) * norm.cdf(z) + sigma * norm.pdf(z)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/_gpr.py:409, in GaussianProcessRegressor.predict(self, X, return_std, return_cov)
#     406 else:
#     407     dtype, ensure_2d = None, False
# --> 409 X = validate_data(self, X, ensure_2d=ensure_2d, dtype=dtype, reset=False)
#     411 if not hasattr(self, "X_train_"):  # Unfitted;predict based on GP prior
#     412     if self.kernel is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:936, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     932     elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     933         # Force object if any of the dtypes is an object
#     934         dtype_orig = object
# --> 936 elif (_is_extension_array_dtype(array) or hasattr(array, "iloc")) and hasattr(
#     937     array, "dtype"
#     938 ):
#     939     # array is a pandas series
#     940     type_if_series = type(array)
#     941     pandas_requires_conversion = _pandas_dtype_needs_early_conversion(array.dtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:733, in _is_extension_array_dtype(array)
#     731 def _is_extension_array_dtype(array):
#     732     # Pandas extension arrays have a dtype with an na_value
# --> 733     return hasattr(array, "dtype") and hasattr(array.dtype, "na_value")
#
# KeyboardInterrupt:

# %%
from sklearn.gaussian_process.kernels import RBF, ConstantKernel

from ba_optimizer_v2 import BayesianOptimizer

optimizer2 = BayesianOptimizer(np.array(X, dtype=np.float64), y, bounds=(0, 1))

kernel = ConstantKernel(1.0, (1e-3, 1e3)) * RBF(1.0, (1e-2, 1e2))

new_submission = optimizer2.optimize_step(
    num_candidates=100000,
    acquisition_func='ei',
    kernel=kernel
)

print(f"\nNEW RECOMMENDATION: {new_submission['best_point']}")
print(f"UCB Score: {new_submission['best_acquisition']:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from sklearn.gaussian_process.kernels import RBF, ConstantKernel
#       3 from ba_optimizer_v2 import BayesianOptimizer
# ----> 5 optimizer2 = BayesianOptimizer(np.array(X, dtype=np.float64), y, bounds=(0, 1))
#       7 kernel = ConstantKernel(1.0, (1e-3, 1e3)) * RBF(1.0, (1e-2, 1e2))
#       9 new_submission = optimizer2.optimize_step(
#      10     num_candidates=100000,
#      11     acquisition_func='ei',
#      12     kernel=kernel
#      13 )
#
# NameError: name 'np' is not defined

# %%
from ba_optimizer_v2 import BayesianOptimizer as BayesianOptimizer_v2
from sklearn.gaussian_process.kernels import Matern, ConstantKernel, WhiteKernel

X = np.array(X, dtype=np.float64)

optimizer_v2 = BayesianOptimizer_v2(X, y, bounds=(0, 1))

kernel = ConstantKernel(1.0, (1e-3, 1e3)) * RBF(length_scale=0.1)
new_submission = optimizer_v2.optimize_step(
    num_candidates=10000,
    acquisition_func='ucb',
    kappa=1.0, kernel=kernel
)

print(f"\n optimizer_v2 NEW RECOMMENDATION: {new_submission['best_point']}")
print(f"optimizer_v2 UCB Score: {new_submission['best_acquisition']:.4f}")
